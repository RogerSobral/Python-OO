# %%
#Importando o pandas
import pandas as pd

# %%
#gerando uma variavel carregada com a planilha
df=pd.read_csv(r"Arrecadacao_01-01-1998_a_31-12-2001.csv" )# usando o header=2 eu posso retirar linhas do cabeçalho desnecessarias

# %%
#df=pd.read_csv(r"Arrecadacao_01-01-1998_a_31-12-2001.csv",usecols=["sg_uf", 'va_arrecadacao'] )
##com o usecols=[] eu posso definir quais colunas eu desejo carregar

# %%
df=pd.read_csv(r"Arrecadacao_01-01-1998_a_31-12-2001.csv", nrows=500 )
## limita a leitura das linhas no numero pedido

# %%
#lendo a base de dados
display(df)
# Out:
#     sg_uf  ano_arrecadacao  mes_arrecadacao  co_tipo_arrecadacao  \
# 0      AC             1998                1                  119
# 1      AC             1998                1                  129
# 2      AC             1998                1                  131
# 3      AC             1998                1                  132
# 4      AC             1998                1                  133
# ..    ...              ...              ...                  ...
# 495    AC             1999                7                  222
# 496    AC             1999                7                  229
# 497    AC             1999                7                  239
# 498    AC             1999                7                  249
# 499    AC             1999                7                  399
#
#      va_arrecadacao            DATA_BASE
# 0             97679  1998-01-01 00:00:00
# 1             11219  1998-01-01 00:00:00
# 2                 0  1998-01-01 00:00:00
# ...

# %%
#lendo uma coluna e verificando suas ocorrencias unicas 
df['sg_uf'].unique()
# Out:
# array(['AC', 'AL', 'AM', 'AP', 'BA', 'CE', 'DF', 'ES', 'GO', 'MA', 'MG',
#        'MS', 'MT', 'PA', 'PB', 'PE', 'PI', 'PR', 'RJ', 'RN', 'RO', 'RR',
#        'RS', 'SC', 'SE', 'SP', 'TO'], dtype=object)

# %%
#lendo uma linha

# %%
df.ano_arrecadacao.head()#você pode plotar uma coluna chamando com .nomedacoluna
# Out:
# 0    1998
# 1    1998
# 2    1998
# 3    1998
# 4    1998
# Name: ano_arrecadacao, dtype: int64

# %%
df.shape # mostra primeiro linhas depois colunas qunatidade
# Out:
# (35, 14)

# %%
df.describe()# pedindo uma descrição dos dados
# Out:
#             Janeiro      Fevereiro          Março         Abril          Maio  \
# count     33.000000      33.000000      33.000000     33.000000     33.000000
# mean    8342.030303    9905.545455   37953.787879   7536.545455   7080.484848
# std    18166.889651   23112.967284  109959.333360  16199.452011  14860.426454
# min        0.000000       0.000000       0.000000      0.000000      0.000000
# 25%      376.000000     192.000000     286.000000    159.000000    124.000000
# 50%     1546.000000    1383.000000    1635.000000   1337.000000   1584.000000
# 75%     6428.000000    5025.000000    5249.000000   5491.000000   6307.000000
# max    91768.000000  108965.000000  417495.000000  82906.000000  77889.000000
#
#               Junho         Julho        Agosto       Setembro       Outubro  \
# count     33.000000     33.000000     33.000000      33.000000     33.000000
# mean    7830.090909   7870.151515   6547.787879   10145.090909   7375.393939
# ...

# %%
df["novo valor"]=df["sg_uf"] #adicionando uma nova coluna, vc pode conctenar colunas com o sinal + sendo do mesmo tipo

# %%
df
# Out:
#     sg_uf  ano_arrecadacao  mes_arrecadacao  co_tipo_arrecadacao  \
# 0      AC             1998                1                  119
# 1      AC             1998                1                  129
# 2      AC             1998                1                  131
# 3      AC             1998                1                  132
# 4      AC             1998                1                  133
# ..    ...              ...              ...                  ...
# 495    AC             1999                7                  222
# 496    AC             1999                7                  229
# 497    AC             1999                7                  239
# 498    AC             1999                7                  249
# 499    AC             1999                7                  399
#
#      va_arrecadacao            DATA_BASE novo valor
# 0             97679  1998-01-01 00:00:00         AC
# 1             11219  1998-01-01 00:00:00         AC
# ...
